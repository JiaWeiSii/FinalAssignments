# %% [markdown]
# <h1>Report on Predicting A Suitable Place to Have a Grocery Shop</h1>

# %% [markdown]
# <h2>Introduction</h2>
#
# This study is to help a startup company who is planning to open their groceries shop/supermarket in Da Nang. Knowing that Da Nang is the most populated city in Vietnam and it is ranked as an important global city based on high quality of living, it is important to know what kind of groceries shop should be invested in the neighborhood (High class, middle class or low class and affordable). However, with limited knowledge of the Toronto market, it is hard for us to do the right decision with a certain amount of budget.
#
# <h2>Problem Statement</h2>
#
# Problem which is tried to solve/ Things we are trying to find out
# 1. Know if it is suitable to open a new groceries shop now
# 2. Where should we open the shop?/ Market Places
# 3. Which kind of shop should we invest?
# 4. Population
# 5. Demographics
# 6. Competitors
#
#
# <h2>Interest</h2>
#
# Our solution needs to be data driven to avoid high risk criteria and increase success rate. Thus, we are going to apply our data science knowledge in the project
#
# <h2>Tools Importing</h2>
# We import all the tools we need
# 1. requests (Library to handle requests)
# 2. Pandas (Library for data analysis)
# 3. Numpy
# 4. Folium
#
# ![image.png](attachment:image.png)
#
# <h2>Apply Credential ID from FourSquare</h2>
#
# ![image.png](attachment:image.png)
#
# <h2>Get requests near Da Nang</h2>
#
# ![image.png](attachment:image.png)
#
# <h2>Transform Data into json then request geocode</h2>
#
# ![image.png](attachment:image.png)
#
#
# <h2>Create group including information</h2>
#
# ![image.png](attachment:image.png)
#
# <h2>Create items of objects grocery and their attributes - id, address, name, etc</h2>
#
# ![image.png](attachment:image.png)
#
# <h2>Create group including information</h2>
#
# From the result, we can know the possible factors used to consider locations that launch our business.
#
# ![image.png](attachment:image.png)
#
# As we can see that there are many grocery shops without address we need to execute hasattr() to determine if each object has a attribute (address).
# Next step we will execute a very important part - get coordinates of Da Nang and create folium map which will help visualize what we have got from data.
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
#
# <h2>Conclusion</h2>
